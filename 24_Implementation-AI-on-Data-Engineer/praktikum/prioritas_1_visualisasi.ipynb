# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("penjualan_dataset.csv")
df
# Out:
#       Tanggal  Jumlah_Penjualan  Harga Kategori_Produk Metode_Pembayaran  \
# 0  2021-01-01                50    100      Elektronik      Kartu Kredit
# 1  2021-01-02                30     50         Fashion     Transfer Bank
# 2  2021-01-03                20    200          Mainan             Tunai
# 3  2021-01-04                40    150       Perhiasan       Kartu Debit
# 4  2021-01-05                60     80        Kosmetik      Kartu Kredit
# 5  2021-01-06                35    120      Elektronik     Transfer Bank
# 6  2021-01-07                45     70         Fashion             Tunai
# 7  2021-01-08                25    180          Mainan       Kartu Debit
# 8  2021-01-09                55     90       Perhiasan     Transfer Bank
# 9  2021-01-10                65     60        Kosmetik      Kartu Kredit
#
#   Lokasi_Pembeli
# 0        Jakarta
# 1        Bandung
# 2       Surabaya
# 3       Semarang
# 4          Medan
# 5        Jakarta
# 6        Bandung
# ...

# %%
# Statistik deskriptif
print("\nStatistik Deskriptif:")
print(df.describe())
# Out:
# Statistik Deskriptif:
#        Jumlah_Penjualan       Harga
# count         10.000000   10.000000
# mean          42.500000  110.000000
# std           15.138252   51.424162
# min           20.000000   50.000000
# 25%           31.250000   72.500000
# 50%           42.500000   95.000000
# 75%           53.750000  142.500000
# max           65.000000  200.000000

# %%
# Visualisasi Jumlah Penjualan per Kategori Produk
plt.figure(figsize=(10, 6))
df.groupby('Kategori_Produk')['Jumlah_Penjualan'].sum().plot(kind='bar', color='skyblue')
plt.title('Total Jumlah Penjualan per Kategori Produk')
plt.xlabel('Kategori Produk')
plt.ylabel('Total Jumlah Penjualan')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
# Visualisasi Jumlah Penjualan per Lokasi Pembelian
plt.figure(figsize=(10, 6))
df.groupby('Lokasi_Pembeli')['Jumlah_Penjualan'].sum().plot(kind='bar', color='lightgreen')
plt.title('Total Jumlah Penjualan per Lokasi Pembelian')
plt.xlabel('Lokasi Pembelian')
plt.ylabel('Total Jumlah Penjualan')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
